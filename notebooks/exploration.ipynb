# %%
import pandas as pd

df = pd.read_csv("../data/dataset.csv")
print(df.shape)
df.head()
# Out:
# (305, 19)
#          Name Team  Attack Points  Attack Errors  Attack Attempts  \
# 0  A. Nikolov  BUL            114             31               85
# 1    Adamczyk  POL             11              1                8
# 2     Adriano  BRA              9              8               13
# 3        Ahyi  NED            109             35               78
# 4        Alan  BRA             80             14               46
#
#    Block Points  Block Errors  Rebounds  Serve Points  Serve Errors  \
# 0             8            20        17            10            29
# 1             3             6         4             1             5
# 2             1             0         5             4             2
# 3            12            19        16             3            30
# 4            13            14        12             4            11
#
#    Serve Attempts  Successful Sets  Set Errors  Set Attempts  Spike Digs  \
# 0              66                5           1            24          39
# 1              23                0           0             3           2
# 2              34                0           0             3           7
# 3              52                1           0            17          27
# 4              59                0           0             6           9
#
#    Dig Errors  Successful Receives  Receive Errors  Receive Attempts
# 0          12                   26              14               134
# 1           4                    0               0                 1
# 2           5                    8               1                28
# 3          21                    0               0                 2
# 4          11                    0               1                 3

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Team',
#  'Attack Points',
#  'Attack Errors',
#  'Attack Attempts',
#  'Block Points',
#  'Block Errors',
#  'Rebounds',
#  'Serve Points',
#  'Serve Errors',
#  'Serve Attempts',
#  'Successful Sets',
#  'Set Errors',
#  'Set Attempts',
#  'Spike Digs',
#  'Dig Errors',
#  'Successful Receives',
#  'Receive Errors',
#  'Receive Attempts']

# %%
print("=== TEAMS ===")
print(f"Number of teams: {df['Team'].nunique()}")
print(df["Team"].unique())
# Out:
# === TEAMS ===
# Number of teams: 18
# ['BUL' 'POL' 'BRA' 'NED' 'CUB' 'IRI' 'ITA' 'ARG' 'TUR' 'GER' 'UKR' 'SLO'
#  'SRB' 'USA' 'FRA' 'CAN' 'JPN' 'CHN']

# %%
print(df.isnull().sum())
df.describe()
# Out:
# Name                   0
# Team                   0
# Attack Points          0
# Attack Errors          0
# Attack Attempts        0
# Block Points           0
# Block Errors           0
# Rebounds               0
# Serve Points           0
# Serve Errors           0
# Serve Attempts         0
# Successful Sets        0
# Set Errors             0
# Set Attempts           0
# Spike Digs             0
# Dig Errors             0
# Successful Receives    0
# Receive Errors         0
# Receive Attempts       0
# dtype: int64
#        Attack Points  Attack Errors  Attack Attempts  Block Points  \
# count     305.000000     305.000000       305.000000    305.000000
# mean       23.085246       7.186885        18.091803      3.986885
# std        29.833958      10.061055        24.324792      5.353291
# min         0.000000       0.000000         0.000000      0.000000
# 25%         0.000000       0.000000         0.000000      0.000000
# 50%         9.000000       3.000000         7.000000      2.000000
# 75%        37.000000      10.000000        27.000000      6.000000
# max       133.000000      46.000000       112.000000     27.000000
#
#        Block Errors    Rebounds  Serve Points  Serve Errors  Serve Attempts  \
# count    305.000000  305.000000    305.000000    305.000000      305.000000
# mean       8.891803    8.963934      2.216393      7.852459       31.131148
# std        9.531014    9.901589      3.033648      8.717489       29.314692
# min        0.000000    0.000000      0.000000      0.000000        0.000000
# 25%        1.000000    0.000000      0.000000      0.000000        2.000000
# 50%        6.000000    6.000000      1.000000      5.000000       25.000000
# 75%       15.000000   14.000000      3.000000     12.000000       53.000000
# max       48.000000   41.000000     15.000000     39.000000      115.000000
#
#        Successful Sets  Set Errors  Set Attempts  Spike Digs  Dig Errors  \
# count       305.000000  305.000000    305.000000  305.000000  305.000000
# mean         13.668852    0.298361     34.491803   12.318033    6.783607
# std          40.699620    0.692652     77.137442   13.706288    7.489404
# min           0.000000    0.000000      0.000000    0.000000    0.000000
# 25%           0.000000    0.000000      2.000000    2.000000    1.000000
# 50%           0.000000    0.000000      7.000000    8.000000    4.000000
# 75%           2.000000    0.000000     21.000000   18.000000   10.000000
# max         275.000000    5.000000    450.000000   69.000000   41.000000
#
#        Successful Receives  Receive Errors  Receive Attempts
# count           305.000000      305.000000        305.000000
# mean              7.609836        2.216393         23.491803
# std              13.458827        3.692862         37.884096
# min               0.000000        0.000000          0.000000
# 25%               0.000000        0.000000          1.000000
# 50%               1.000000        0.000000          4.000000
# 75%               8.000000        3.000000         28.000000
# max              81.000000       20.000000        150.000000

# %%
team_stats = df.drop(columns=["Name"]).groupby("Team").agg({
    "Attack Points": "sum",
    "Attack Errors": "sum",
    "Attack Attempts": "sum",
    "Block Points": "sum",
    "Block Errors": "sum",
    "Rebounds": "sum",
    "Serve Points": "sum",
    "Serve Errors": "sum",
    "Serve Attempts": "sum",
    "Successful Sets": "sum",
    "Set Errors": "sum",
    "Set Attempts": "sum",
    "Spike Digs": "sum",
    "Dig Errors": "sum",
    "Successful Receives": "sum",
    "Receive Errors": "sum",
    "Receive Attempts": "sum",
}).reset_index()

team_stats["Attack Efficiency"] = team_stats["Attack Points"] / (team_stats["Attack Attempts"] + 1)
team_stats["Serve Efficiency"] = team_stats["Serve Points"] / (team_stats["Serve Attempts"] + 1)
team_stats["Block Efficiency"] = team_stats["Block Points"] / (team_stats["Block Errors"] + 1)

print(f"Number of teams: {len(team_stats)}")
team_stats.head(15)
# Out:
# Number of teams: 18
#    Team  Attack Points  Attack Errors  Attack Attempts  Block Points  \
# 0   ARG            400            120              319            67
# 1   BRA            425            109              284            64
# 2   BUL            353            110              299            71
# 3   CAN            387            118              299            62
# 4   CHN            317            111              282            54
# 5   CUB            429            148              311            92
# 6   FRA            417            112              338            74
# 7   GER            441            144              364            66
# 8   IRI            431            143              276            66
# 9   ITA            430            109              339            82
# 10  JPN            393            112              292            37
# 11  NED            399            134              340            68
# 12  POL            413            109              323            76
# 13  SLO            360            125              305            56
# 14  SRB            348            132              253            68
#
#     Block Errors  Rebounds  Serve Points  Serve Errors  Serve Attempts  ...  \
# 0            131       145            39           158             527  ...
# 1            164       151            40           104             571  ...
# 2            141       165            39           152             466  ...
# 3            150       150            46           146             522  ...
# 4            127       114            22            84             465  ...
# 5            193       176            45           148             586  ...
# 6            150       157            41           156             532  ...
# 7            160       195            37           164             596  ...
# 8            169       122            46           140             592  ...
# 9            171       181            50           129             588  ...
# 10           126       135            43           113             522  ...
# 11           135       133            25           140             507  ...
# 12           156       170            32           126             571  ...
# 13           139       167            40           124             492  ...
# 14           157       138            22           123             477  ...
#
#     Set Errors  Set Attempts  Spike Digs  Dig Errors  Successful Receives  \
# 0            8           865         237         107                  119
# 1            3           515         168         154                  114
# 2            4           554         180          77                   95
# 3            3           573         188         145                  146
# 4            7           538         155         130                  104
# 5            4           372         172          95                   91
# 6            7           578         254          94                  168
# 7            1           683         280         121                  148
# 8            9           625         246          97                  152
# 9            5           615         234         118                  129
# 10           7           542         213          95                  142
# 11           2           627         220         134                  182
# 12           8           581         200         156                  119
# 13           6           583         210          93                  111
# 14           5           551         175         104                  127
#
#     Receive Errors  Receive Attempts  Attack Efficiency  Serve Efficiency  \
# 0               35               404           1.250000          0.073864
# 1               29               393           1.491228          0.069930
# 2               46               390           1.176667          0.083512
# 3               41               387           1.290000          0.087954
# 4               41               371           1.120141          0.047210
# 5               22               301           1.375000          0.076661
# 6               31               363           1.230088          0.076923
# 7               36               442           1.208219          0.061977
# 8               40               408           1.555957          0.077572
# 9               35               407           1.264706          0.084890
# 10              22               335           1.341297          0.082218
# 11              33               403           1.170088          0.049213
# 12              41               376           1.274691          0.055944
# 13              42               382           1.176471          0.081136
# 14              53               399           1.370079          0.046025
#
#     Block Efficiency
# 0           0.507576
# 1           0.387879
# 2           0.500000
# 3           0.410596
# 4           0.421875
# 5           0.474227
# 6           0.490066
# 7           0.409938
# 8           0.388235
# 9           0.476744
# 10          0.291339
# 11          0.500000
# 12          0.484076
# 13          0.400000
# 14          0.430380
#
# [15 rows x 21 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

positive_stats = [
    "Attack Points", "Block Points", "Serve Points",
    "Rebounds", "Spike Digs", "Successful Receives",
    "Successful Sets", "Attack Efficiency", "Serve Efficiency",
    "Block Efficiency"
]

negative_stats = [
    "Attack Errors", "Block Errors", "Serve Errors",
    "Set Errors", "Dig Errors", "Receive Errors"
]

scaler = MinMaxScaler()
team_scores = team_stats.copy()
all_cols = positive_stats + negative_stats
team_scores[all_cols] = scaler.fit_transform(team_stats[all_cols])

# %%
team_scores["Strength Score"] = (
    team_scores[positive_stats].mean(axis=1) * 100 -
    team_scores[negative_stats].mean(axis=1) * 30
)

min_score = team_scores["Strength Score"].min()
max_score = team_scores["Strength Score"].max()
team_scores["Strength Score"] = (
    (team_scores["Strength Score"] - min_score) /
    (max_score - min_score) * 100
)

rankings = team_scores[["Team", "Strength Score"]].sort_values(
    "Strength Score", ascending=False
).reset_index(drop=True)

rankings.index += 1
print("=== TEAM STRENGTH RANKINGS ===")
print(rankings)
# Out:
# === TEAM STRENGTH RANKINGS ===
#    Team  Strength Score
# 1   ITA      100.000000
# 2   FRA       92.135770
# 3   UKR       83.008820
# 4   GER       76.522722
# 5   ARG       75.787872
# 6   IRI       72.783838
# 7   BRA       70.154487
# 8   CAN       65.703991
# 9   CUB       65.428307
# 10  JPN       62.608724
# 11  BUL       57.202961
# 12  USA       56.752958
# 13  POL       55.917442
# 14  NED       53.858748
# 15  SLO       52.256816
# 16  TUR       28.593008
# 17  SRB       21.288590
# 18  CHN        0.000000

# %%
import numpy as np

def simulate_match(team_a, team_b, team_scores, team_stats):
    """
    Simulates a volleyball match between two teams.
    Returns sets won by each team and a probability of team_a winning.
    
    In volleyball, a team wins a match by winning 3 sets.
    Sets can end 25-x (first 4 sets) or 15-x (deciding set).
    """
    score_a = team_scores.loc[team_scores["Team"] == team_a, "Strength Score"].values[0]
    score_b = team_scores.loc[team_scores["Team"] == team_b, "Strength Score"].values[0]
    
    diff = score_a - score_b
    prob_a_wins = 1 / (1 + np.exp(-diff / 20))
    
    sets_a, sets_b = 0, 0
    set_scores = []
    
    while sets_a < 3 and sets_b < 3:
        is_deciding_set = (sets_a + sets_b == 4)
        max_points = 15 if is_deciding_set else 25
        
        if np.random.random() < prob_a_wins:
            points_a = max_points
            points_b = np.random.randint(max_points - 10, max_points - 1)
            sets_a += 1
        else:
            points_b = max_points
            points_a = np.random.randint(max_points - 10, max_points - 1)
            sets_b += 1
        
        set_scores.append((points_a, points_b))
    
    return {
        "team_a": team_a,
        "team_b": team_b,
        "sets_a": sets_a,
        "sets_b": sets_b,
        "set_scores": set_scores,
        "prob_a_wins": round(prob_a_wins * 100, 1)
    }

# Test with two teams
result = simulate_match("JPN", "ITA", team_scores, team_stats)
print(f"{result['team_a']} vs {result['team_b']}")
print(f"Sets: {result['sets_a']} - {result['sets_b']}")
print(f"Set scores: {result['set_scores']}")
print(f"Win probability for {result['team_a']}: {result['prob_a_wins']}%")
# Out:
# JPN vs ITA
# Sets: 2 - 3
# Set scores: [(25, 21), (25, 20), (23, 25), (18, 25), (12, 15)]
# Win probability for JPN: 13.4%
